# %%
import pandas as pd

# %%
df1 = pd.read_csv('distiluse_tSNE_hdbscan_0.01.csv')
df1['cluster'].value_counts()
# Out:
# cluster
# 1     14860
# 2      7058
# 0      4518
# 6      3871
# 3      3622
# 5      3329
# 9      3005
# 11     2937
# 8      2893
# 7      2570
# 4      2321
# 10      767
# Name: count, dtype: int64

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51751 entries, 0 to 51750
# Data columns (total 37 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   name_board         51751 non-null  object
#  1   creator_thread     51565 non-null  object
#  2   creator_id_thread  51751 non-null  int64
#  3   name_thread        51751 non-null  object
#  4   created_on         51751 non-null  object
#  5   registration_date  50432 non-null  object
#  6   total_posts        50432 non-null  float64
#  7   reputation         50432 non-null  float64
#  8   creator_post       51751 non-null  object
#  9   creator_id_post    51751 non-null  int64
#  10  content            51751 non-null  object
#  11  created_on_post    51751 non-null  object
#  12  cluster            51751 non-null  int64
#  13  index              51751 non-null  int64
#  14  size_percentage    51751 non-null  float64
#  15  n_1_topics         51751 non-null  object
# ...

# %%
df1[df1['cluster'] == 1][['name_thread', 'n_1_topics', 'n_2_topics']]
# Out:
#                                              name_thread  \
# 36891  Anyone seen heard MorpheusLabs Good USA mdma v...
# 36892           MDMA vendor germany Netherlands ship usa
# 36893                                domestic vendor LSD
# 36894                US vendor Blue Punishers ww ship US
# 36895                                 vendor selling AMT
# ...                                                  ...
# 51746                                        Safe ground
# 51747                                          long long
# 51748                                      link CanadaHQ
# 51749                                          pgp Login
# 51750                     cannacreations Giveaway Update
#
#                                               n_1_topics  \
# 36891  [('mdmadirtsharkresellers', 0.3637), ('ukdrugd...
# 36892  [('mdmadirtsharkresellers', 0.3637), ('ukdrugd...
# 36893  [('mdmadirtsharkresellers', 0.3637), ('ukdrugd...
# ...
