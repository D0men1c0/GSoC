# %% [markdown]
# # Library

# %%
import pandas as pd
import os
from tqdm import tqdm
import matplotlib.pyplot as plt
pd.set_option('display.max_columns', None) 
pd.set_option('display.width', None)

# %% [markdown]
# # Create a Dataframe for each clusters of csv files

# %%
folder_path = '.'
csv_files = [f for f in os.listdir(folder_path) if f.endswith('.csv')]

# %%
results = []
# Read each CSV file and calculate the value_counts for the 'cluster' attribute
for file in tqdm(csv_files, desc='Reading files', unit='file'):
    file_path = os.path.join(folder_path, file)
    df = pd.read_csv(file_path)
    
    if 'cluster' in df.columns:
        value_counts = df['cluster'].value_counts()
        for cluster, count in value_counts.items():
            results.append({'file': file.rstrip('.csv'), 'cluster': cluster, 'count': count})
    else:
        print(f'The file {file} does not contain the "cluster" column.')
# Out:
# Reading files: 100%|██████████| 16/16 [01:16<00:00,  4.78s/file]

# %%
df_results = pd.DataFrame(results)
pivot_table = df_results.pivot_table(index='file', columns='cluster', values='count', fill_value=0).astype(int)
pivot_table['Total'] = pivot_table.sum(axis=1)
pivot_table
# Out:
# cluster                                             0      1      2      3  \
# file
# distiluse_UMAP_hdbscan_not_batch_0.02_window30   6062   1391   3822   3413
# distiluse_UMAP_kmeans_10_window30                6582   8196   6967  12488
# distiluse_UMAP_kmeans_15_window30                7285   6375   3591   7354
# distiluse_nored_agglomerative_10                18704  16810   5333   9796
# distiluse_nored_kmeans_10_window30               8365  11445   3526   2278
# distiluse_tSNE_agglomerative_10                  9154   8315   7560   6312
# distiluse_tSNE_agglomerative_15                  4806   4629   4861   3972
# distiluse_tSNE_agglomerative_20                  4710   4335   3861   3905
# distiluse_tSNE_agglomerative_5                  18430  16432  11481  11688
# distiluse_tSNE_hdbscan_0.01                      4518  14860   7058   3622
# distiluse_tSNE_hdbscan_0.02_window30             7171   9419  24278   6722
# distiluse_tSNE_hdbscan_0.03_window30            11140  14438  11754   7445
# distiluse_tSNE_hdbscan_notbatch_0.01_window30    2125   5777    695   3227
# distiluse_tSNE_hdbscan_notbatch_0.02_window30    6716  29622   6372  12181
# distiluse_tSNE_kmeans_10_window30                5246   8163   6535   6717
# distiluse_tSNE_kmeans_15_window30                5032   4703   5488   3164
#
# cluster                                            4     5     6      7     8  \
# file
# distiluse_UMAP_hdbscan_not_batch_0.02_window30  5467  3853     0      0     0
# distiluse_UMAP_kmeans_10_window30               1648  9712  8495   3309  3322
# distiluse_UMAP_kmeans_15_window30               4950  6982  3996   5761  1115
# distiluse_nored_agglomerative_10                2825  2610  3293   3282  1845
# distiluse_nored_kmeans_10_window30              3345  7590  5366  11812  4171
# distiluse_tSNE_agglomerative_10                 7765  5190  6264   6224  5017
# distiluse_tSNE_agglomerative_15                 4353  4000  2809   3056  3065
# distiluse_tSNE_agglomerative_20                 4464  3829  3717   2455  3238
# distiluse_tSNE_agglomerative_5                  8704     0     0      0     0
# distiluse_tSNE_hdbscan_0.01                     2321  3329  3871   2570  2893
# distiluse_tSNE_hdbscan_0.02_window30            5073     0     0      0     0
# distiluse_tSNE_hdbscan_0.03_window30               0     0     0      0     0
# distiluse_tSNE_hdbscan_notbatch_0.01_window30   3051  1986  9871   1714  5684
# distiluse_tSNE_hdbscan_notbatch_0.02_window30   3106  4805     0      0     0
# distiluse_tSNE_kmeans_10_window30               7299  8310  5989   6075  6867
# distiluse_tSNE_kmeans_15_window30               4632  4795  4221   4822  4277
#
# cluster                                            9    10    11    12    13  \
# file
# distiluse_UMAP_hdbscan_not_batch_0.02_window30     0     0     0     0     0
# distiluse_UMAP_kmeans_10_window30               6016     0     0     0     0
# distiluse_UMAP_kmeans_15_window30               4871  2454  4546  2477  1947
# distiluse_nored_agglomerative_10                2237     0     0     0     0
# distiluse_nored_kmeans_10_window30              8837     0     0     0     0
# distiluse_tSNE_agglomerative_10                 4934     0     0     0     0
# distiluse_tSNE_agglomerative_15                 3144  2802  3532  4150  2716
# distiluse_tSNE_agglomerative_20                 3778  3715  3803  2815  3021
# distiluse_tSNE_agglomerative_5                     0     0     0     0     0
# distiluse_tSNE_hdbscan_0.01                     3005   767  2937     0     0
# distiluse_tSNE_hdbscan_0.02_window30               0     0     0     0     0
# distiluse_tSNE_hdbscan_0.03_window30               0     0     0     0     0
# distiluse_tSNE_hdbscan_notbatch_0.01_window30   1404  1072  1593  2660  2412
# distiluse_tSNE_hdbscan_notbatch_0.02_window30      0     0     0     0     0
# distiluse_tSNE_kmeans_10_window30               5534     0     0     0     0
# distiluse_tSNE_kmeans_15_window30               3577  4281  4681  4899  4519
#
# cluster                                           14    15    16    17    18  \
# file
# distiluse_UMAP_hdbscan_not_batch_0.02_window30     0     0     0     0     0
# distiluse_UMAP_kmeans_10_window30                  0     0     0     0     0
# distiluse_UMAP_kmeans_15_window30               3031     0     0     0     0
# distiluse_nored_agglomerative_10                   0     0     0     0     0
# distiluse_nored_kmeans_10_window30                 0     0     0     0     0
# distiluse_tSNE_agglomerative_10                    0     0     0     0     0
# distiluse_tSNE_agglomerative_15                 2465  2339  2852  2559  2466
# distiluse_tSNE_agglomerative_20                 3565  2088  2630  2318  2065
# distiluse_tSNE_agglomerative_5                     0     0     0     0     0
# distiluse_tSNE_hdbscan_0.01                        0     0     0     0     0
# distiluse_tSNE_hdbscan_0.02_window30               0     0     0     0     0
# distiluse_tSNE_hdbscan_0.03_window30               0     0     0     0     0
# distiluse_tSNE_hdbscan_notbatch_0.01_window30   2958  1978  1429  1327  2566
# distiluse_tSNE_hdbscan_notbatch_0.02_window30      0     0     0     0     0
# distiluse_tSNE_kmeans_10_window30                  0     0     0     0     0
# distiluse_tSNE_kmeans_15_window30               3644     0     0     0     0
#
# cluster                                           19  Total
# file
# distiluse_UMAP_hdbscan_not_batch_0.02_window30     0  24008
# distiluse_UMAP_kmeans_10_window30                  0  66735
# distiluse_UMAP_kmeans_15_window30                  0  66735
# distiluse_nored_agglomerative_10                   0  66735
# distiluse_nored_kmeans_10_window30                 0  66735
# distiluse_tSNE_agglomerative_10                    0  66735
# distiluse_tSNE_agglomerative_15                 2159  66735
# distiluse_tSNE_agglomerative_20                 2423  66735
# distiluse_tSNE_agglomerative_5                     0  66735
# distiluse_tSNE_hdbscan_0.01                        0  51751
# distiluse_tSNE_hdbscan_0.02_window30               0  52663
# distiluse_tSNE_hdbscan_0.03_window30               0  44777
# distiluse_tSNE_hdbscan_notbatch_0.01_window30   1138  54667
# distiluse_tSNE_hdbscan_notbatch_0.02_window30      0  62802
# distiluse_tSNE_kmeans_10_window30                  0  66735
# distiluse_tSNE_kmeans_15_window30                  0  66735

# %% [markdown]
# # Plot Distribution

# %%
try:
    pivot_table.drop(columns='Total', inplace=True)
except KeyError:
    pass
# Calculate number of subplot rows needed
num_files = len(pivot_table.index)
num_cols = 2
num_rows = (num_files + num_cols - 1) // num_cols

# Create subplots
fig, axs = plt.subplots(num_rows, num_cols, figsize=(15, num_rows * 5))
fig.subplots_adjust(hspace=0.5)

# Iterate over each file and create pie charts
for idx, file in enumerate(pivot_table.index):
    row = idx // num_cols
    col = idx % num_cols
    ax = axs[row, col]
    
    cluster_counts = pivot_table.loc[file]
    labels = cluster_counts.index[cluster_counts > 0]  # Select only clusters with count > 0
    sizes = cluster_counts[cluster_counts > 0].values

    wedges, texts, autotexts = ax.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=140)
    ax.set_aspect('equal')
    ax.set_title(f'Cluster Distribution for {file}')
    ax.legend(wedges, labels, title="Clusters", loc="center left", bbox_to_anchor=(1, 0, 0.5, 1))

# Remove any empty subplots if the number of files doesn't fill all subplots
for idx in range(num_files, num_rows * num_cols):
    row = idx // num_cols
    col = idx % num_cols
    fig.delaxes(axs[row, col])

plt.tight_layout()
plt.show()

# %%
num_files = len(pivot_table.index)
num_cols = 2
num_rows = (num_files + num_cols - 1) // num_cols  # Round up division

# Create subplots
fig, axs = plt.subplots(num_rows, num_cols, figsize=(15, num_rows * 5))
fig.subplots_adjust(hspace=0.5)

for idx, file in enumerate(pivot_table.index):
    row = idx // num_cols
    col = idx % num_cols
    ax = axs[row, col]
    
    cluster_counts = pivot_table.loc[file]
    labels = cluster_counts.index[cluster_counts > 0]  # Select only clusters with count > 0
    sizes = cluster_counts[cluster_counts > 0].values

    ax.bar(labels, sizes, align='center', alpha=0.7)
    ax.set_xlabel('Cluster')
    ax.set_ylabel('Count')
    ax.set_title(f'Cluster Distribution for {file}')
    
# Remove any empty subplots if the number of files doesn't fill all subplots
for idx in range(num_files, num_rows * num_cols):
    row = idx // num_cols
    col = idx % num_cols
    fig.delaxes(axs[row, col])

plt.tight_layout()
plt.show()
